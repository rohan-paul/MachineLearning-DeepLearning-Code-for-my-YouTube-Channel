# %% [markdown]
# ## Visualization of Activation FUnction
#
# ### [Link to my Youtube Video Explaining this whole Notebook](https://www.youtube.com/watch?v=SWqDVkYnSYQ&list=PLxqBkZuBynVQqJTE9nRM2p7Tb12TDPlnq&index=9)
#
# [![Imgur](https://imgur.com/VxrKTU5.png)](https://www.youtube.com/watch?v=SWqDVkYnSYQ&list=PLxqBkZuBynVQqJTE9nRM2p7Tb12TDPlnq&index=9)

# %% [markdown]
# ## RELU

# %%
import torch.nn.functional as F
from torch.autograd import Variable
import matplotlib.pyplot as plt
import torch
# %matplotlib inline

# %% [markdown]
# ### TORCH.LINSPACE
#
# ![](assets/2022-02-22-22-16-19.png)

# %%
x = torch.linspace(-10, 10, 2000) 
x.shape

x = Variable(x)
x_numpy = x.data.numpy() 
x_numpy.shape
# Out:
# (2000,)

# %% [markdown]
# ## Define all the Activation Functions

# %%
torch_relu = F.relu(x).data.numpy()

torch_tanh = torch.tanh(x).data.numpy()

torch_sigmoid = torch.sigmoid(x).data.numpy()

torch_softplus = F.softplus(x).data.numpy()

torch_leaky_relu = F.leaky_relu(x).data.numpy()

# %% [markdown]
# ## RELU Plot
#
# The range in which
# this activation function operates is from 0 to infinity. It is mostly used
# between different hidden layers in a neural network model.

# %%
plt.figure(figsize=(7, 4))
plt.plot(x_numpy, torch_relu, c='r', label='ReLU')
plt.ylim((-1, 10))
plt.legend(loc='best')

# %% [markdown]
# ## Sigmoid Plot

# %%
plt.figure(figsize=(7, 4))
plt.plot(x_numpy, torch_sigmoid, c='r', label='sigmoid')
plt.ylim((-0.2, 1.2))
plt.legend(loc='best')

# %% [markdown]
# ## Tanh Plot

# %%
plt.figure(figsize=(7, 4))
plt.plot(x_numpy, torch_tanh, c='r', label='tanh')
plt.ylim((-1.2, 1.2))
plt.legend(loc='best')

# %% [markdown]
# ## Softplus Plot
#
# ![](assets/2022-02-22-22-15-06.png)

# %%
plt.figure(figsize=(7, 4))
plt.plot(x_numpy, torch_softplus, c='r', label='softplus')
plt.ylim((-0.2, 11))
plt.legend(loc='best')

# %% [markdown]
# ## Leaky Relu
#
# ![](assets/2022-02-22-22-19-14.png)
#
# In a standard neural network model, a dying gradient problem is common.
# To avoid this issue, leaky ReLU is applied. Leaky ReLU allows a small and
# non-zero gradient when the unit is not active.

# %%
plt.figure(figsize=(7, 4))
plt.plot(x_numpy, torch_leaky_relu, c='r', label='Leaky ReLU')
plt.ylim((-0.2, 11))
plt.legend(loc='best')
