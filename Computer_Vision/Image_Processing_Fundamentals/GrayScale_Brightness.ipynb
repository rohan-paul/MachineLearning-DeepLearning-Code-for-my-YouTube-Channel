# %%
from PIL import Image, ImageDraw
import numpy as np
# from numpy import asarray

# %%
image = Image.open('./image.jpg')
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=984x656 at 0x7F277435E730>

# %%
(0, 0)
